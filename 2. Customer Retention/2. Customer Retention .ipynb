# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading data set

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
df=pd.read_excel(r'C:\Users\m\Desktop\csv files\Customer_retention_dataset\customer_retention_dataset.xlsx',
                   header=None,skiprows=1)

# %% [markdown]
# # Checking shape of data

# %%
df.shape
# Out:
# (269, 71)

# %%
df.head()
# Out:
#        0            1              2       3              4   \
# 0    Male  31-40 years          Delhi  110009  Above 4 years
# 1  Female  21-30 years          Delhi  110030  Above 4 years
# 2  Female  21-30 years  Greater Noida  201308      3-4 years
# 3    Male  21-30 years        Karnal   132001      3-4 years
# 4  Female  21-30 years     Bangalore   530068      2-3 years
#
#                    5                6           7           8   \
# 0         31-40 times          Dial-up     Desktop      Others
# 1  41 times and above            Wi-Fi  Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone  4.7 inches
#
#                       9              10                 11               12  \
# 0  Window/windows Mobile  Google chrome      Search Engine    Search Engine
# ...

# %% [markdown]
# # Checking for missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Checking information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       269 non-null    object
#  1   1       269 non-null    object
#  2   2       269 non-null    object
#  3   3       269 non-null    int64
#  4   4       269 non-null    object
#  5   5       269 non-null    object
#  6   6       269 non-null    object
#  7   7       269 non-null    object
#  8   8       269 non-null    object
#  9   9       269 non-null    object
#  10  10      269 non-null    object
#  11  11      269 non-null    object
#  12  12      269 non-null    object
#  13  13      269 non-null    object
#  14  14      269 non-null    object
#  15  15      269 non-null    object
#  16  16      269 non-null    object
#  17  17      269 non-null    object
#  18  18      269 non-null    object
#  19  19      269 non-null    object
#  20  20      269 non-null    object
# ...

# %% [markdown]
# All the columns are of object type except Pincode

# %% [markdown]
# # Renaming columns

# %%
df.rename(columns={0:"Gender",
                   1:"Age",
                   2:'Shopping City',
                   3:"Pincode",
                   4:"Since How Long You are Shopping Online",
                   5:"times online purchase in past 1 year",
                   6:"internet access",
                   7:"device use",
                   8:"screensize of Device",
                   9:"OS of device",
                   10:"browser used",
                   11:'Which channel did you follow to arrive at your favorite online store for the first time',
                   12:"After first visit, how do you reach the online retail store",
                   13:"How much time do you explore the e- retail store before making a purchase decision",
                   14:"preferred payment Option",
                   15:"abandon your shopping cart",
                   16:"Why did you abandon the Shopping Cart",
                   17:"content on the website must be easy to read and understand",
                   18:"Information on similar product to the one highlighted is important for product comparison",
                   19:"Complete information on listed seller and product being offered is important for purchase decision",
                   20:"All relevant information on listed products must be stated clearly",
                   21:"Ease of navigation in website",
                   22:"Loading and processing speed",
                   23:"User friendly Interface of the website",
                   24:"Convenient Payment methods",
                   25:"Trust that the online retail store will fulfill its part of the transaction at the stipulated time",
                   26:"Empathy towards the customers",
                   27:"Being able to guarantee the privacy of the customer",
                   28:"Responsiveness, availability of several communication channels",
                   29:"Online shopping gives monetary benefit and discounts",
                   30:"Enjoyment is derived from shopping online",
                   31:"Shopping online is convenient and flexible",
                   32:"Return and replacement policy of the e-tailer is important for purchase decision",
                   33:"Gaining access to loyalty programs is a benefit of shopping online",
                   34:"Displaying quality Information on the website improves satisfaction of customers",
                   35:"User derive satisfaction while shopping on a good quality website or application",
                   36:"Net Benefit derived from shopping online can lead to users satisfaction",
                   37:"User satisfaction cannot exist without trust",
                   38:"Offering a wide variety of listed product in several category",
                   39:"Provision of complete and relevant product information",
                   40:"Monetary savings",
                   41:"The Convenience of patronizing the online retailer",
                   42:"Shopping on the website gives you the sense of adventure",
                   43:"Shopping on your preferred e-tailer enhances your social status",
                   44:"You feel gratification shopping on your favorite e-tailer",
                   45:"Shopping on the website helps you fulfill certain roles",
                   46:"Getting value for money spent",
                   47:"online retailers you have shopped from",
                   48:"Easy to use website or application",
                   49:"Visual appealing web-page layout",
                   50:"Wild variety of product on offer",
                   51:"Complete, relevant description information of products",
                   52:"Fast loading website speed of website and application",
                   53:"Reliability of the website or application",
                   54:"Quickness to complete purchase",
                   55:"Availability of several payment options",
                   56:"Speedy order delivery",
                   57:"Privacy of customers information",
                   58:"Security of customer financial information",
                   59:"Perceived Trustworthiness",
                   60:"Presence of online assistance through multi-channel",
                   61:"Longer time to get logged in",
                   62:"Longer time in displaying graphics and photos",
                   63:"Late declaration of price",
                   64:"Longer page loading time",
                   65:"Limited mode of payment on most products",
                   66:"Longer delivery period",
                   67:"Change in website/Application design",
                   68:"Frequent disruption when moving from one page to another",
                   69:"Website is as efficient as before",
                   70:"Which of the Indian online retailer would you recommend to a friend"}, inplace=True)

# %% [markdown]
# # Data Cleaning

# %%
df['times online purchase in past 1 year'].replace('42 times and above','41 times and above',inplace=True)
df["internet access"].replace('Mobile internet',"Mobile Internet",inplace=True)

# %%
df.head(2)
# Out:
#    Gender          Age Shopping City  Pincode  \
# 0    Male  31-40 years         Delhi   110009
# 1  Female  21-30 years         Delhi   110030
#
#   Since How Long You are Shopping Online times online purchase in past 1 year  \
# 0                          Above 4 years                          31-40 times
# 1                          Above 4 years                   41 times and above
#
#   internet access  device use screensize of Device           OS of device  \
# 0         Dial-up     Desktop               Others  Window/windows Mobile
# 1           Wi-Fi  Smartphone           4.7 inches                IOS/Mac
#
#     browser used  \
# 0  Google chrome
# 1  Google chrome
#
#   Which channel did you follow to arrive at your favorite online store for the first time  \
# 0                                      Search Engine
# 1                                      Search Engine
#
#   After first visit, how do you reach the online retail store  \
# ...

# %% [markdown]
# # Lets start the Analysis

# %%
sns.set_style('dark')
plt.figure(figsize=(8,6))
plt.title('Distribution of Gender',fontsize=17,color="b")
plt.xlabel("Gender",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15)
ax = (df.Gender.value_counts()/len(df)*100).sort_index().plot(kind="bar", rot=0 ,color=['#F05EDA','#08B7CF'],
                                                              linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 )

# %% [markdown]
# From the above plot it is clear that Female customers are more than male, Female customers are about 67 % and male are 32%.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of Shopping City',fontsize=17,color="b")
plt.xlabel("Shopping City",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['Shopping City'].value_counts()/len(df)*100).plot(kind="bar", rot=90,
    linewidth=2,edgecolor='k',color=["#1f77b4","#ff7f0e","#2ca02c","#d62728","#9467bd","#8c564b",
                                     "#e377c2","#7f7f7f", "#bcbd22","#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['Shopping City'])
plt.title('Distribution of Shopping City',fontsize=17,color="b")
plt.xlabel("Shopping City",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# From the above plot we can observed that maximum people who are shop on online plateform are from Delhi (about 21.6% )

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of Age',fontsize=17,color="b")
plt.xlabel("Age",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['Age'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['Age'],edgecolor='k',linewidth=2)
plt.title('Distribution of Age',fontsize=17,color="b")
plt.xlabel("Age",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# From the above plot we can observed that customers whose age is in between 31-40 are more interested in online shopping (about 30%)
# ,Customers who are above 51 are not so interested in online shopping.
# Customers whose age is less that 20 are also not shop much from online shopping.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of Since How Long You are Shopping Online',fontsize=17,color="b")
plt.xlabel("Years",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['Since How Long You are Shopping Online'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['Since How Long You are Shopping Online'],edgecolor='k',linewidth=2)
plt.title('Distribution of Since How Long You are Shopping Online',fontsize=17,color="b")
plt.xlabel("Years",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# Above plot is about "since how many years the person has shopping Online" and we can observed from the above plot that there are 36.4 % customers who were shopping online above 4 years. There are 16% customers who were shopping online less than 1 year.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of times online purchase in past 1 year',fontsize=17,color="b")
plt.xlabel("Number of times",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['times online purchase in past 1 year'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['times online purchase in past 1 year'],edgecolor='k',linewidth=2)
plt.title('Distribution of times online purchase in past 1 year',fontsize=17,color="b")
plt.xlabel("Number of times",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# There are 42 % customers who shopped from online less than 10 times , 23% customers shopped 31-40 times.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of internet access',fontsize=17,color="b")
plt.xlabel("source of internet",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['internet access'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['internet access'],edgecolor='k',linewidth=2)
plt.title('Distribution of internet access',fontsize=17,color="b")
plt.xlabel("source of internet",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# 70% customers use mobile internet for shopping.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of device use',fontsize=17,color="b")
plt.xlabel("Device use",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['device use'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
sns.countplot(df['device use'],edgecolor='k',linewidth=2)
plt.title('Distribution of device use',fontsize=17,color="b")
plt.xlabel("Device use",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# More than half of the customers are using smartphone for the online shopping.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of browser used',fontsize=17,color="b")
plt.xlabel("browser used",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['browser used'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,
    edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['browser used'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',
   color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of browser used',fontsize=17,color="b")
plt.xlabel("Browser used",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# From the above plot it is clear that majority of the customers are using Google chrome browser to shop online.
# only 1.9% customers are using Mozilla Firefox.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of channel',fontsize=17,color="b")
plt.xlabel("channel followed to arrive at your favorite online store",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['Which channel did you follow to arrive at your favorite online store for the first time'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['Which channel did you follow to arrive at your favorite online store for the first time'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of channel ',fontsize=17,color="b")
plt.xlabel("channel followed to arrive at your favorite online store",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of way to reach online retail store',fontsize=17,color="b")
plt.xlabel("way to reach online retail store",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['After first visit, how do you reach the online retail store'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['After first visit, how do you reach the online retail store'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of way to reach online retail store ',fontsize=17,color="b")
plt.xlabel("way to reach online retail store",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# - 32.3% customers reach online store by search engine.
# - 32 % reach via application.
# - 26% customers reach the online store using Direct url.
# - 6.7% reach via email and
# - only 3% reach via social media which is very less.
#
# conclusions:
# - 32.3 % customers use search engine to reach online store which means they are not a reguler buyer or they don't have much space to download the application.
# - 32 % customers have installed application on there device which indicateds that they are interested in shopping and do often shopping.
# - 6.7% customers reach to store via email which means those emails are not enough convencing to make them click on mail and send them to online store.
# - only 3 % customers reach via Social media it may be because of lake of advertisement or the content on the advertisement is not so convencing.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of preferred payment Option',fontsize=17,color="b")
plt.xlabel("preferred payment Option",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['preferred payment Option'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['preferred payment Option'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of preferred payment Option',fontsize=17,color="b")
plt.xlabel("preferred payment Option",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# - 55 % customers preferred credit/Debit cards to pay.
# - 28 % customers preferred cash on delivery may be because of Lack of trust.
# - only 16.7 % customers pay by E-wallets which is not a convencing stats.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of time do you explore the e- retail store',fontsize=17,color="b")
plt.xlabel("Time",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['How much time do you explore the e- retail store before making a purchase decision'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['How much time do you explore the e- retail store before making a purchase decision'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of time do you explore the e- retail store',fontsize=17,color="b")
plt.xlabel("Time",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# - 45% customers spend more than 15 minut which means they are interested in shopping and looking for their product to buy.
# - 26% customers spend 6-10 minut which means they added their product to cart before and buy it or may be they do not like the product on the online store.
# - 5.6 % customers spend less than 1 minut which means they accidently opened the application by clicking on link or application.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of abandon your shopping cart',fontsize=17,color="b")
plt.xlabel("Time",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['abandon your shopping cart'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['abandon your shopping cart'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of abandon your shopping cart',fontsize=17,color="b")
plt.xlabel("Time",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# - There are only 17% customers who never abandon their shopping cart which means they shopped whenever they opened the online store.
# - 63% customers abandon their cart sometimes.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.set_style('dark')
plt.title('Distribution of reason of abandon shopping cart',fontsize=17,color="b")
plt.xlabel("Reason",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
ax = (df['Why did you abandon the Shopping Cart'].value_counts()/len(df)*100).plot(kind="bar", rot=90 ,linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"],)
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    
plt.subplot(1,2,2)
df['Why did you abandon the Shopping Cart'].value_counts().plot(kind='bar',linewidth=2,edgecolor='k',color=["#800080","#966F33","#800000","#34282C","#E8ADAA","#4CC417","#98FF98","#FF6700"])
plt.title('Distribution of reason of abandon shopping cart',fontsize=17,color="b")
plt.xlabel("Reason",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.show()

# %% [markdown]
# - 11 % customers abandon their cart because of "Lake of trust" which is very big reason and not good for the online shopping company hence thay have to make sure that the product and the product quality they showed online  will reach to the customer as it is.
# - 49% abandon their cart because of alternaive offers.
# - 5.2 % customers abandon their cart because of not getting their preferred mode of payment so the online company should think about it and add all the mode of payment.

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=['#08B7CF','#F05EDA'])
sns.catplot(x = 'Age', data = df, kind = 'count', hue = 'Gender',height=6, aspect=14/8,linewidth=2,edgecolor='k')
plt.xlabel("Shopping City",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.legend(fontsize=17)
plt.show()

# %% [markdown]
# From the above plot we can observed that in each age group female customers are more as compare to male customers.

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=['#08B7CF','#F05EDA'])
sns.catplot(x = 'Shopping City', data = df, kind = 'count', hue = 'Gender',height=6, aspect=14/8,linewidth=2,edgecolor='k')
plt.xlabel("Shopping City",fontsize=17,color="r")
plt.ylabel('Count',fontsize=17,color="r")
plt.xticks(fontsize=15,rotation=90)
plt.legend(fontsize=17)
plt.show()

# %% [markdown]
# - From the above catplot we can observed that from delhi males are shopping more then Females.
# - But in Greater Noida very less number of male customers are shopping but the female are shopping in high number.
# - Only Delhi,Noida & Moradabad are the places where male customers are more else every city female customers are shopping more.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df["content on the website must be easy to read and understand"].value_counts().plot.pie(autopct="%.1f%%",
        fontsize=12,colors=["#00008B","#FF6700","#E8ADAA","#4CC417","#800080","#966F33","#800000","#34282C"])
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title("Content on the website must be easy to read and understand",fontsize=17,color="red")
plt.ylabel(' ',fontsize=13,color="r")

plt.subplot(2,2,2)
male=df[df['Gender']=='Male']
plt.title("Male's Opinion",fontsize=17,color="b")
plt.xlabel("Opinion",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(male["content on the website must be easy to read and understand"].value_counts()/len(male)*100).plot(kind="bar",
                            color=['#08B7CF'],rot=0 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(male)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 

plt.subplot(2,2,3)
female=df[df['Gender']=='Female']
plt.title("Female's Opinion",fontsize=17,color="b")
plt.xlabel("Opinion",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(female["content on the website must be easy to read and understand"].value_counts()/len(female)*100).plot(kind="bar",
                                    color=['#F05EDA'],rot=0 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(female)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
plt.show()

# %% [markdown]
# <bold>Here we plotted 3 different plot</bold><br>
# - 1. Donut chart shows overall opinion of male & Female Customers
# - 2. Frequency % of male's opinion.
# - 3. Frequency % of female's opinion.
# - From the above plots we can observed that ovrall opinion for 'content on the website must be easy to read and understand' is strongly agreed it means customers need content on the website is easy to understand.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df["Why did you abandon the Shopping Cart"].value_counts().plot.pie(autopct="%.1f%%",fontsize=12,colors=["#00008B","#FF6700","#E8ADAA","#4CC417","#800080","#966F33","#800000","#34282C"])
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title("Why did you abandon the Shopping Cart",fontsize=17,color="red")
plt.ylabel(' ',fontsize=13,color="r")

plt.subplot(2,2,2)
male=df[df['Gender']=='Male']
plt.title("Male's Opinion",fontsize=17,color="b")
plt.xlabel("Reason",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(male["Why did you abandon the Shopping Cart"].value_counts()/len(male)*100).plot(kind="bar",color=['#08B7CF'],rot=90 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(male)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 

plt.subplot(2,2,3)
female=df[df['Gender']=='Female']
plt.title("Female's Opinion",fontsize=17,color="b")
plt.xlabel("Reason",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(female["Why did you abandon the Shopping Cart"].value_counts()/len(female)*100).plot(kind="bar",color=['#F05EDA'],rot=90 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(female)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
plt.show()

# %% [markdown]
# <bold>Here we plotted 3 different plot</bold><br>
# - From the above plots we can observed that ovarall 49 % customers abandon their shopping cart because of better alternative offers.
# - But only 39% male customer abandon cart because of better alternative but 54% female abandon their cart because of better alternative offers
# - seems like male customers are more dependent of promocode while shopping as compare to female customers.
# - overall 5 % customers abandon their cart because of no prefered payment mode.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df["Information on similar product to the one highlighted is important for product comparison"].value_counts().plot.pie(autopct="%.1f%%",fontsize=12,colors=["#00008B","#FF6700","#E8ADAA","#4CC417","#800080","#966F33","#800000","#34282C"])
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title("Information on similar product comparison",fontsize=17,color="red")
plt.ylabel(' ',fontsize=13,color="r")

plt.subplot(2,2,2)
male=df[df['Gender']=='Male']
plt.title("Male's Opinion",fontsize=17,color="b")
plt.xlabel("Opinion",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(male["Information on similar product to the one highlighted is important for product comparison"].value_counts()/len(male)*100).plot(kind="bar",color=['#08B7CF'],rot=0 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(male)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 

plt.subplot(2,2,3)
female=df[df['Gender']=='Female']
plt.title("Female's Opinion",fontsize=17,color="b")
plt.xlabel("Opinion",fontsize=17,color="r")
plt.ylabel('Frequency [%]',fontsize=17,color="r")
plt.xticks(fontsize=11,rotation=90)
ax=(female["Information on similar product to the one highlighted is important for product comparison"].value_counts()/len(female)*100).plot(kind="bar",color=['#F05EDA'],rot=0 ,linewidth=2,edgecolor='k')
ax.set_yticks(np.arange(0, 110, 10))
ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(female)/100)
for p in ax.patches:
    ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
plt.show()

# %% [markdown]
# - from the above plots it is clear that female customers are strongly agree for the statement that "Information on similar product to the one highlighted is important for product comparison",
# and male are just agree to do same.

# %%
for i in df.columns[19:-24]:
    print(i)
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    male=df[df['Gender']=='Male']
    plt.title("Male's Opinion",fontsize=17,color="b")
    plt.xlabel("Opinion",fontsize=17,color="r")
    plt.ylabel('Frequency [%]',fontsize=17,color="r")
    plt.xticks(fontsize=11,rotation=90)
    ax=(male[i].value_counts()/len(male)*100).plot(kind="bar",color=['#08B7CF'],rot=0 ,linewidth=2,edgecolor='k')
    ax.set_yticks(np.arange(0, 110, 10))
    ax2 = ax.twinx()
    ax2.set_yticks(np.arange(0, 110, 10)*len(male)/100)
    for p in ax.patches:
        ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 

    plt.subplot(1,2,2)
    female=df[df['Gender']=='Female']
    plt.title("Female's Opinion",fontsize=17,color="b")
    plt.xlabel("Opinion",fontsize=17,color="r")
    plt.ylabel('Frequency [%]',fontsize=17,color="r")
    plt.xticks(fontsize=11,rotation=90)
    ax=(female[i].value_counts()/len(female)*100).plot(kind="bar",color=['#F05EDA'],rot=0 ,linewidth=2,edgecolor='k')
    ax.set_yticks(np.arange(0, 110, 10))
    ax2 = ax.twinx()
    ax2.set_yticks(np.arange(0, 110, 10)*len(female)/100)
    for p in ax.patches:
        ax.annotate('{:.1f}%'.format(p.get_height()), (p.get_x()+0.18, p.get_height()+2),fontsize=12 ) 
    plt.show()
plt.show()
# Out:
# Complete information on listed seller and product being offered is important for purchase decision
# All relevant information on listed products must be stated clearly
# Ease of navigation in website
# Loading and processing speed
# User friendly Interface of the website
# Convenient Payment methods
# Trust that the online retail store will fulfill its part of the transaction at the stipulated time
# Empathy towards the customers
# Being able to guarantee the privacy of the customer
# Responsiveness, availability of several communication channels
# Online shopping gives monetary benefit and discounts
# Enjoyment is derived from shopping online
# Shopping online is convenient and flexible
# Return and replacement policy of the e-tailer is important for purchase decision
# Gaining access to loyalty programs is a benefit of shopping online
# Displaying quality Information on the website improves satisfaction of customers
# ...

# %% [markdown]
# #### Observatioins:
# - 45% males customers agree about the statement that Complete information on listed seller and product being offered is important for purchase decision and 38 % girls are strongly agreed about this statement.
# - 53 % male agree about All relevant information on listed products must be stated clearly
# - Female Customers thinks that User friendly Interface of the website is needed to shop.
# - 69% female customers thinks that there should be a convenient payment mode to pay bills.
# - 79 % Female customers have a opinion that Empathy towards the customers is necessary.
# - 72 % females wants that the company being able to guarantee the privacy of the customer.
# - only 40% male customers thinks that Shopping online is convenient and flexible and 60% girls thinks that Shopping online is convenient and flexible it means all the online shopping company should focuse on females to increase there revenue.
# - 79 % females strongly agreed about the statement that Return and replacement policy of the e-tailer is important for purchase decision
# - 53 % male and 56 % female customers feel that online shopping is the place of getting value for money spent.

# %%
for i in df.columns[-24:]:
    Company=['Amazon.in', 'Flipkart.com', 'Paytm.com', 'Myntra.com', 'Snapdeal.com']  
    Amazon=df[i].str.contains("Amazon.in|Amazon.com", na=False).sum()/len(df)*100
    Flipcart=df[i].str.contains("Flipkart.com", na=False).sum()/len(df)*100
    paytm=(df[i].str.contains("Paytm.com|Patym.com", na=False).sum()/len(df)*100)
    Myntra= df[i].str.contains("Myntra.com", na=False).sum()/len(df)*100
    Snapdeal=df[i].str.contains("Snapdeal.com|Snapdeal|snapdeal", na=False).sum()/len(df)*100
    df1=pd.DataFrame({"Company":Company,"Percentage %":[Amazon,Flipcart,paytm,Myntra,Snapdeal]})

    plt.figure(figsize=(8,4))
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=["#00008B","#FF6700","#E8ADAA","#4CC417","#800080","#966F33"
                                                        ,"#800000","#34282C"])
    sns.barplot(df1["Company"],df1["Percentage %"],linewidth=2,edgecolor='k')
    plt.title(f"Customer's Opinion for {i}",fontsize=17,color="b")
    plt.xlabel("Company",fontsize=17,color="r")
    plt.ylabel("Percentage",fontsize=17,color="r")
    plt.xticks(fontsize=13,rotation=0)
    plt.yticks(fontsize=13,rotation=0)
    plt.show()

# %% [markdown]
# <!-- <body></body>
# <h4></h4> -->
# <!-- <ul></ul> -->
# #### Observations
# Here We took opinions from the customers
# <body>
# <h4> Opinion From customers for online retailers you have shopped from</h4>
# <ul>100% of the customers have shopped from Amazon.in</ul>
# <ul>80% of the customers have shopped from FlipKart.com</ul>
# <ul>50% customers used Paytm.com for shopping</ul>
# <ul>55% used myntra for shopping</ul>
# <ul>70% have shopped from Snapdeal.com</ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Easy to use website or application</h4>
# <ul>Approx 90 % customers have a opinion that Amazone.in is the easiest website to use.</ul>
#     <ul>After Amazon.in, Flipkart is the easy to use application</ul>
#     <ul>Approx 50% customers thinks that paytm.com is not a easy website to use </ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Visual appealing web-page layout</h4>
#     <ul>85% customers thinks that Amazon.in is the best website in terms of visual layout</ul>
#     <ul>25% thinks that paytm and snapdeal is the visual appealing website</ul>
#    </body>
#
# <body>
#     <h4> Opinion From customers for Wild variety of product on offer</h4>
#     <ul>Most of the customers thinks that Amazone & Flipkart has the wild variety of Products</ul>
#     <ul>25% customers thgink that myntra has the wild range of product.it is less becaause myntra sales only fashion brands</ul>
#     <ul>only 8 % people think that Snapdeal has the wild variety of product</ul>
#   </body>
#
# <body>
#     <h4> Opinion From customers for Complete, relevant description information of products</h4>
#     <ul>customers think that Amazone & Flipkart mention complete & relevant description information of products</ul>
#     <ul>Else all websites need to improve </ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Fast loading website speed of website and application</h4>
#     <ul>90% customer feels that amazone .in is the Fast loading website speed of website and application</ul>
#     <ul>After that Flikart comes</ul>
#
# </body>
#
# <body>
#     <h4> Opinion From customers for Reliability of the website or application</h4>
#       <ul>85 % customers have a openion that amazon is the most reliable website</ul>
#     <ul>Snapdeal is the worst among all the websites</ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Availability of several payment options</h4>
#     <ul>Amazon and flipkart provide all type of payment option hence people thinks that these website is good</ul>
#     <ul>customers thinks paytm.com do not variety in payment options </ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Speedy order delivery</h4>
#     <ul>Amazon is the company who delivers the product very fast </ul>
#     <ul>Flipkart comes after amazon</ul>
#     <ul>none of the customers thinks that paytm.com delivered the product fast </ul>
#
# </body>
#
# <body>
#     <h4> Opinion From customers for Late declaration of price</h4>
# <ul>Maximum customers thinks that myntra.com is the company who declares the price of product late</ul>
# <ul>After that paytm and snapdeal comes</ul>
#
# </body>
#
# <body>
#     <h4> Opinion From customers for Limited mode of payment on most products</h4>
#
# <ul> customers thinks that Snapdeal and Amazon have the limited mode of payment on most products</ul>
#
#
# </body>
#
# <body>
#     <h4> Opinion From customers for Change in website/Application design</h4>
#     <ul>customers thinks that Amazon is the company who Change in website/Application design frequently</ul>
#     <ul></ul>
#     <ul></ul>
#     <ul></ul>
#     </body>
#
#  <body>
#     <h4> Opinion From customers for Website is as efficient as before</h4>
#     <ul>70% customers thinks that Amazon company's Website is as efficient as before</ul>
#     <ul>After that Flipkart and paytm comes </ul>
#     <ul>It looks like myntra.com is not updating their website</ul>
#     <ul></ul>
# </body>
#
# <body>
#     <h4> Opinion From customers for Which of the Indian online retailer would you recommend to a friend
# </h4>
# <ul>80% customers recommend Amazon.com to their friend</ul>
# <ul>45% customers recommend Flipkart.com to their friend</ul>
# <ul>15% customers recommend Paytm.com to their friend</ul>
# <ul>30% customers recommend Myntra.com to their friend</ul>
# <ul>05% customers recommend Snapdeal.com to their friend</ul>
#
# </body>

# %% [markdown]
# # Overall Observations

# %% [markdown]
# - From gender I can say male are less and female are more means female use to do more shopping
# - From age 21-30 and 31-40 years of people use to do more shopping and peoples who are 50 years old and above they do very less shopping
# - From Since How Long You are Shopping Online I can say peoples at the age of 4 years start online shopping
# - From How many times you have made an online purchase in the past 1 year I can say less then 10 times has high count and and 42 times and above have least count means mostly people buy less then 10 mines a year
# - From How do you access the internet while shopping on-line we can see people used to buy using mobile internet more and very few use dialup
# - From Which device do you use to access the online shopping I can say people use there smartphones more then laptops and very few uses tablet
# - From What is the screen size of your mobile device I can say other have the highest count as 5.5 inch and least 5 inch size
# - From What is the operating system (OS) of your device I can say mostly people use window phones then android and then less people use ios for inline shopping
# - From What browser do you run on your device to access the website I can say mostly all people use google crome and very less people use firefox
# - From Which channel did you follow to arrive at your favorite online store for the first time People mostly use search engine to buy something
# - From After first visit, how do you reach the online retail store I can say people used search engine or app for this
# - From How much time do you explore the e- retail store before making a purchase decision i can say mostly people use to take 15 min and very few people take 1 min only
# - From What is your preferred payment Option i can say mostly people use credit/debit card then 2nd prefrence of people are cash on delivery then least they use E-wallet
# - From  How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart i can say the highest count have sometimes and the least count have very frequently
# - From reason to abandon purchase from shopping cart I can say better offer has the high count means people get some other best offer and it has least count of lack of trust and no prefered payment means people dont have trust and they dont find there best preffered method
# - From The content on the website must be easy to read and understand people have voted more for strongly agree and agree they want while shopping they can easily read the content of site
# - From Information on similar product to the one highlighted  is important for product comparison I can say people have voted strongly agree and agree on this
#
#
# - Above 41-50 years and less than 20 years, female and male respondents count difference is not much.
# - From Bangalore and Greater Noida, many respondents are female.
# - From Noida and Delhi, many respondents are male.
# - Both men and women shopping from desktop count are almost same. However, more women shop from either smartphone or laptop.
# - Most of the women come back to shopping website by using search engine.
# - Many women prefer to use search engine or app, rather than direct URL. However, men prefer to use search engine and Url and app little less. So we can understand that women use app more than men.
# - Women spend more time than men during online shopping and the time is mostly more than 15 mins, followed by 11-15 mins.
# - Women too compare the products with other websites and is one of the reasons to leave the cart without shopping.
# - Women prefer more loyalpoints than men.
# - More women disagree that online shopping is a kind of adventure. So websites need to work towards giving real time experience as this can be a big marketing strategy.
# - Women dont feel that online shopping fulfills certain roles.
#
#
# - There are more women respondents than men. It could be that data collection is mainly focused on women.
# - Amongst the respondents, the major class targetted is between 21-40 years, followed by 41-50 and less than 20 years. We can understand that the correspondents are mostly from working class.
# - The respondents are majorly residing in cities like Delhi, Greater Noida, Noida and Bangalore.
# - Majority are shopping online for more than 4 years. There are considerable people who are shopping online since less than one year and also it shows that many new customers are being added every year.
# - We can observe that many have shopped less than 10 times in the past year.
# - Many of them use mobile to shop online, followed by laptop, desktop and tablet.
# - Windows constitute the major OS of the customer device, followed by Android and Mac.
# - Google Chrome is majorly used to access the shopping website.
# - People are becoming customers of their favorite stores by using the search engine. Content marketing or display advertisements are not that impactful when coming to online marketing. So companies should spend more on advertising on search engines.
# - For repeated visits, people use search engine first, followed by app and direct URL. We can see that difference between app and search engine is small.
# - Majority of the people spend more than 15 minutes before making a purchase, followed by 6-10 minutes.
# - The major payment method used by all is credit/debit cards, followed by COD and e-wallets.
# - People have mentioned that sometimes they would leave the cart without purchasing and the major reason they have mentioned is that they are finding some better alternative offer. It means that people are comparing from many online websites before making any purchase.
# - Customers strongly agree that content of website must be easy to read and understandable.
# - Majority of customers want information of similar products to make purchase.
# - Majority of the customers want complete information on listed sellers and their products being offered.
# - Customers want all relevant information on the listed products and very less customers disagree to that.
# - The customers wanted the websites to be easily navigated.
# - Majority of the customers wanted high loading and processing speed, user friendly interface of website, convenient payment method, high trust on website, empathy towards customers, guarantee privacy of customers, responsiveness-availability of several communication channels, etc.
# - People feel that online shopping provides monitory benefits and discounts.
# - Customers also feel that shopping online is convenient and flexible.
# - Return policy is important for deciding the product purchase to many customers.
# - Many customers find shopping through online helps them financially because of cost and discount factors.
# - When it comes to certain factors like gratification, social status enhancement because of shopping, or whether shopping online gives a thrill or adventure, customers are more indifferent to these. So, there is an ample scope in giving more enhanced experienced to customers in this regard.

# %% [markdown]
# # Shortcomings in the companies and the ways to improve those shortcomings.

# %% [markdown]
# ### <u>Amazon.com</u>
# #### The highlights of the company:
#
# - Fast delivery of products.
# - Availability of complete information of the products.
# - Presence of online assistance through multi-channels.
# - Reliable website or app, perceived trustworthiness.
# - Best website in terms of visual layout.
# - Website is as efficient as before
#
# ####  Areas where company needs to improve:
# - Give more payment options to customers.
# - Try to give price early during promotion.
# - Need to decrease the page loading time.
#
#
# ### <u>Flipkart.com</u>
# #### The highlights of the company:
# - Speedy order delivery
# - Easy to use website.
# - Availibility of serval Payment options.
# - Reliable website or app, perceived trustworthiness.
# - Wild variety of products to offer.
# - Convenient to use and also a good website for shopping.
# - Fast delivery of products.
# - Availability of complete information of the products.
#
# ####  Areas where company needs to improve:
# - Need to increase the speed to product delivery
# - Give more payment options to customers.
# - Try to give the price early during promotion.
# - Need to decrease the page loading time.
#
# ### <u>Patym.com</u>
# #### The highlights of the company:
# - Easy to use website
# - Quickness to complete purchase
# - Availibility of serval Payment options.
#
# ####  Areas where company needs to improve:
# - website takes longer time to display photos and graphics
# - Reduce the delivery time of the products during promotions.
# - Try to give the price early during promotion.
# - During promotions, try to give a disturbance free shopping experience to customers.
# - Late declaration of price and discounts.
# - Frequent disturbance is occurring while moving from one page to another.
#
#
# ### <u>Myntra.com</u>
# #### The highlights of the company:
# - Convenient to use and also a good website.
# - Availability of several payment options.
# - Faster products delivery.
# - Complete information of products available.
# - Reliable website or app, perceived trustworthiness.
# - Wild variety of product to offer
#
# ####  Areas where company needs to improve:
# - Needs to increase the speed of delivery
# - Need to increase the variety of product on offer.
# - Need to add more payment options .
# - During promotions, try to give a disturbance free shopping experience to customers.
# - Try to give the price early during promotions.
# - Reduce the delivery time of the products during promotions.
#
#
# ### <u>Snapdeal.com</u>
# #### The highlights of the company:
# - Easy to use Website.
# - Availability of several payment options.
# - Insure security of customers financial information.
#
# ####  Areas where company needs to improve:
# - Reduce the delivery time of the products during promotions.
# - Try to give the price early during promotion.
# - During promotions, try to give a disturbance free shopping experience to customers.
# - Late declaration of price and discounts.
# - No one has expressed to recommend snapdeal to a contact as it has the most negative feedbacks among all other websites.
